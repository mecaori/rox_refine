# %% [markdown]
# https://cdn.discordapp.com/attachments/967820822515445760/967995372796522546/unknown.png

# %%
import random

# price 
p_ori = 2400
p_enrich_ori = 9000
p_reduce_prevent = 10000

state = [6, 6, 12, 12, 6, 6, 12, 12]

chance = [
    (100, 0 , 0 , 0), 
    (50, 50, 0, 0),
    (33, 66, 0, 0),
    (25, 75, 0, 0),
    (25, 40, 25, 10),
    (25, 40, 25, 10),
    (20, 40, 25, 15),
    (20, 40, 25, 15)
]

chance_re = [
    (100, 0 , 0 , 0), 
    (50, 50, 0, 0),
    (33, 66, 0, 0),
    (25, 75, 0, 0),
    (20, 60, 0, 20),
    (13.33, 61.67, 0, 25),
    (10, 60, 0, 30),
    (6.67, 58.33, 0, 35)
]

# %%
def refining(refine, cost):
    # click    
    sampleList = ['success', 'fail', 'reduce', 'break']
  
    status = random.choices(
        sampleList, weights=chance[refine], k=1)
    
    # calculate cost
    if refine >= 4:
        cost = cost + state[refine]*p_enrich_ori
    else:
        cost = cost + state[refine]*p_ori
    
    # change refine value
    if status == ['success']:
        refine = refine + 1
    elif status == ['reduce']:
        refine = refine -1
    else:
        refine = refine
    
    return refine, cost

# %%
def refining_re(refine, cost):
    # click    
    sampleList = ['success', 'fail', 'reduce', 'break']
  
    status = random.choices(
        sampleList, weights=chance_re[refine], k=1)
    
    # calculate cost
    if refine >= 4:
        cost = cost + state[refine]*p_enrich_ori + state[refine]*p_reduce_prevent
    else:
        cost = cost + state[refine]*p_ori
    
    # change refine value
    if status == ['success']:
        refine = refine + 1
    elif status == ['reduce']:
        refine = refine -1
    else:
        refine = refine
    
    return refine, cost

# %%
# ไม่ใช้่กันลด
refine = 0
cost = 0

while refine != 8:
    refine, cost = refining(refine, cost)
    print('บวก ',refine,' ใช้เงิน ', cost)
# Out:
# บวก  1  ใช้เงิน  14400
# บวก  1  ใช้เงิน  28800
# บวก  1  ใช้เงิน  43200
# บวก  2  ใช้เงิน  57600
# บวก  3  ใช้เงิน  86400
# บวก  3  ใช้เงิน  115200
# บวก  4  ใช้เงิน  144000
# บวก  4  ใช้เงิน  198000
# บวก  3  ใช้เงิน  252000
# บวก  4  ใช้เงิน  280800
# บวก  3  ใช้เงิน  334800
# บวก  4  ใช้เงิน  363600
# บวก  4  ใช้เงิน  417600
# บวก  5  ใช้เงิน  471600
# บวก  5  ใช้เงิน  525600
# บวก  5  ใช้เงิน  579600
# บวก  5  ใช้เงิน  633600
# บวก  5  ใช้เงิน  687600
# บวก  6  ใช้เงิน  741600
# บวก  5  ใช้เงิน  849600
# บวก  5  ใช้เงิน  903600
# บวก  5  ใช้เงิน  957600
# บวก  5  ใช้เงิน  1011600
# บวก  5  ใช้เงิน  1065600
# บวก  6  ใช้เงิน  1119600
# บวก  6  ใช้เงิน  1227600
# บวก  6  ใช้เงิน  1335600
# บวก  6  ใช้เงิน  1443600
# บวก  7  ใช้เงิน  1551600
# บวก  7  ใช้เงิน  1659600
# บวก  6  ใช้เงิน  1767600
# บวก  7  ใช้เงิน  1875600
# บวก  7  ใช้เงิน  1983600
# บวก  7  ใช้เงิน  2091600
# บวก  6  ใช้เงิน  2199600
# บวก  6  ใช้เงิน  2307600
# บวก  6  ใช้เงิน  2415600
# บวก  6  ใช้เงิน  2523600
# บวก  6  ใช้เงิน  2631600
# บวก  5  ใช้เงิน  2739600
# บวก  6  ใช้เงิน  2793600
# บวก  6  ใช้เงิน  2901600
# บวก  6  ใช้เงิน  3009600
# บวก  5  ใช้เงิน  3117600
# บวก  6  ใช้เงิน  3171600
# บวก  5  ใช้เงิน  3279600
# บวก  5  ใช้เงิน  3333600
# บวก  4  ใช้เงิน  3387600
# บวก  5  ใช้เงิน  3441600
# บวก  6  ใช้เงิน  3495600
# บวก  7  ใช้เงิน  3603600
# บวก  7  ใช้เงิน  3711600
# บวก  7  ใช้เงิน  3819600
# บวก  7  ใช้เงิน  3927600
# บวก  7  ใช้เงิน  4035600
# บวก  7  ใช้เงิน  4143600
# บวก  7  ใช้เงิน  4251600
# บวก  7  ใช้เงิน  4359600
# บวก  7  ใช้เงิน  4467600
# บวก  7  ใช้เงิน  4575600
# บวก  7  ใช้เงิน  4683600
# บวก  7  ใช้เงิน  4791600
# บวก  7  ใช้เงิน  4899600
# บวก  8  ใช้เงิน  5007600

# %%
# ใช้กันลด
refine = 0
cost = 0

while refine != 8:
    refine, cost = refining_re(refine, cost)
    print('บวก ',refine,' ใช้เงิน ', cost)
# Out:
# บวก  1  ใช้เงิน  14400
# บวก  1  ใช้เงิน  28800
# บวก  2  ใช้เงิน  43200
# บวก  2  ใช้เงิน  72000
# บวก  2  ใช้เงิน  100800
# บวก  2  ใช้เงิน  129600
# บวก  2  ใช้เงิน  158400
# บวก  3  ใช้เงิน  187200
# บวก  4  ใช้เงิน  216000
# บวก  4  ใช้เงิน  270000
# บวก  4  ใช้เงิน  324000
# บวก  4  ใช้เงิน  378000
# บวก  4  ใช้เงิน  432000
# บวก  4  ใช้เงิน  486000
# บวก  4  ใช้เงิน  540000
# บวก  4  ใช้เงิน  594000
# บวก  4  ใช้เงิน  648000
# บวก  4  ใช้เงิน  702000
# บวก  5  ใช้เงิน  756000
# บวก  5  ใช้เงิน  810000
# บวก  5  ใช้เงิน  864000
# บวก  5  ใช้เงิน  918000
# บวก  6  ใช้เงิน  972000
# บวก  6  ใช้เงิน  1080000
# บวก  6  ใช้เงิน  1188000
# บวก  6  ใช้เงิน  1296000
# บวก  6  ใช้เงิน  1404000
# บวก  6  ใช้เงิน  1512000
# บวก  6  ใช้เงิน  1620000
# บวก  7  ใช้เงิน  1728000
# บวก  7  ใช้เงิน  1836000
# บวก  7  ใช้เงิน  1944000
# บวก  7  ใช้เงิน  2052000
# บวก  7  ใช้เงิน  2160000
# บวก  7  ใช้เงิน  2268000
# บวก  7  ใช้เงิน  2376000
# บวก  7  ใช้เงิน  2484000
# บวก  7  ใช้เงิน  2592000
# บวก  7  ใช้เงิน  2700000
# บวก  7  ใช้เงิน  2808000
# บวก  7  ใช้เงิน  2916000
# บวก  7  ใช้เงิน  3024000
# บวก  7  ใช้เงิน  3132000
# บวก  7  ใช้เงิน  3240000
# บวก  7  ใช้เงิน  3348000
# บวก  7  ใช้เงิน  3456000
# บวก  7  ใช้เงิน  3564000
# บวก  7  ใช้เงิน  3672000
# บวก  7  ใช้เงิน  3780000
# บวก  7  ใช้เงิน  3888000
# บวก  7  ใช้เงิน  3996000
# บวก  7  ใช้เงิน  4104000
# บวก  7  ใช้เงิน  4212000
# บวก  7  ใช้เงิน  4320000
# บวก  7  ใช้เงิน  4428000
# บวก  7  ใช้เงิน  4536000
# บวก  7  ใช้เงิน  4644000
# บวก  7  ใช้เงิน  4752000
# บวก  7  ใช้เงิน  4860000
# บวก  7  ใช้เงิน  4968000
# บวก  7  ใช้เงิน  5076000
# บวก  7  ใช้เงิน  5184000
# บวก  7  ใช้เงิน  5292000
# บวก  7  ใช้เงิน  5400000
# บวก  7  ใช้เงิน  5508000
# บวก  7  ใช้เงิน  5616000
# บวก  7  ใช้เงิน  5724000
# บวก  7  ใช้เงิน  5832000
# บวก  7  ใช้เงิน  5940000
# บวก  7  ใช้เงิน  6048000
# บวก  7  ใช้เงิน  6156000
# บวก  7  ใช้เงิน  6264000
# บวก  8  ใช้เงิน  6372000

# %%
sum_1 = 0
sum_2 = 0

for i in range(0,10000):
    refine = 0
    cost = 0

    while refine != 8:
        refine, cost = refining(refine, cost)
    sum_1 = sum_1 + cost
    
    refine = 0
    cost = 0

    while refine != 8:
        refine, cost = refining_re(refine, cost)
    sum_2 = sum_2 + cost

if sum_1/100 > sum_2/100:
    print('ไม่ใช้กันลดดีกว่า')
else:
    print('ใช้กันลดดีกว่า')
# Out:
# ไม่ใช้กันลดดีกว่า
